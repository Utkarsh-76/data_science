# %%
from tabula import read_pdf

df = read_pdf('C:\Users\agarutk\Documents\git_repos\data_science\Syllabus_comparison\syllabus\host\diploma_host\DBS5028.pdf',pandas_options = {'header': None, }).set_index([0])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-e4a8901bfa7e> in <module>()
#       1 from tabula import read_pdf
#       2
# ----> 3 df = read_pdf('C:\Users\agarutk\Documents\git_repos\data_science\Syllabus_comparison\syllabus\host\diploma_host\DBS5028.pdf',pandas_options = {'header': None, }).set_index([0])
#
# C:\Anaconda2\lib\site-packages\tabula\wrapper.pyc in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, **kwargs)
#     103
#     104     if not os.path.exists(path):
# --> 105         raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     106
#     107     try:
#
# IOError: [Errno 2] No such file or directory: 'C:\\Users\x07garutk\\Documents\\git_repos\\data_science\\Syllabus_comparison\\syllabus\\host\\diploma_host\\DBS5028.pdf'

# %%
df
# Out:
#          1                                                  2
# 0
#  1.0     .                          Name of Course E-Commerce
#  2.0     .                                Course Code DBS5028
#  3.0     .  Type of Course Core for Diploma in Business Ad...
# NaN    NaN  (e.g. : Core, major, elective etc.) Elective f...
# NaN    NaN  Information Systems, Diploma in Accounting, Di...
# NaN    NaN                                        Engineering
#  4.0     .  Synopsis This course provides an overview of e...
# NaN    NaN  marketing and advertising, mobile commerce, so...
# NaN    NaN  commerce security and payment systems. Student...
# NaN    NaN  of e-commerce business models, revenue models ...
# NaN    NaN                    starting a new online business.
#  5.0     .                         Version Current: June 2017
# NaN    NaN  (State the date of theSenate’s approval - prev...
# NaN    NaN     New version : ADC Nov 2017 Senate 195 Jan 2018
# ...

# %%
data = {}
data['course_name'] = df.loc[1.0,2].encode('ascii','ignore')[15:]
data['course_credit'] = df.loc[8.0,2].encode('ascii','ignore')[13:]

# %%
data
# Out:
# {'course_credit': '3', 'course_name': 'E-Commerce'}

# %%
df.iloc[57:67,1]
# Out:
# 0
# NaN                      Overview of Electronic Commerce
# NaN    Definition of Electronic Commerce (EC); Catego...
# NaN          of EC; EC Framework; Major Types of EC CLO1
# NaN                                          1 2 2 1 3 8
# NaN    Transactions; EC 2.0; Elements of the Digital ...
# NaN      Drivers of EC; EC Business Models; Benefits and
# NaN                                    Limitations of EC
# NaN         E-Commerce: Mechanisms, Infrastructures, and
# NaN                                                Tools
# NaN       Major EC Activities and Mechanisms; Components
# Name: 2, dtype: object
